# %%
#| hide
from algorithmic_gamer.types import *
from algorithmic_gamer.fuzzer import *
from algorithmic_gamer.vision import *

from datetime import datetime
import matplotlib.pyplot as plt

# %% [markdown]
# # algorithmic-gamer

# %% [markdown]
# algorithmic-gamer is a collection of functionality for making artificial intelligences that can play games. currently built for windows. Features vision from any application or defined of your screen, collecting observation episodes from game play and enables your model to interact with the game pad. It is still a wip, feel free to submit changes

# %% [markdown]
# ## How to Install

# %% [markdown]
# ```sh
# git clone https://github.com/TannerLaBorde/algorithmic-gamer.git
# pip install -e '.[dev]'
# ```

# %% [markdown]
# ## Example usage

# %% [markdown]
# ### vision

# %%
#|eval: false
reg = Region(left=400, top=400, right=1400, bottom=1000)
img = f_view(reg)
img.shape, plt.imshow(img)
# Out:
# ((601, 1001, 3), <matplotlib.image.AxesImage>)

# %%
#|eval: false
win = Window(app_name=fuzzy_app('shannon'))
img2 = f_view(win)
img2.shape, plt.imshow(img2)
# Out:
# ((184, 226, 3), <matplotlib.image.AxesImage>)

# %%
#|eval: false
VisualEventObservation(datetime.utcnow(), img).visualize()
